# %% [markdown]
# #abcde

# %% [markdown]
# Run this notebook on Google Colab.
# Be sure to opload the abcd repository to your drive and unzip abcd/data/abcd_v1.1-json.gz first.

# %% [markdown]
# ##Preparation tasks

# %% [markdown]
# ###Copy files to runtime

# %% [markdown]
# Copy the files to runtime for additional flexibility.

# %%
# !cp -r drive/MyDrive/abcde/components .
# !cp -r drive/MyDrive/abcde/data .
# !cp -r drive/MyDrive/abcde/utils .
# !cp -r drive/MyDrive/abcde/outputs .
# !cp -r drive/MyDrive/abcde/main.py .

# %% [markdown]
# ###Install required libraries

# %% [markdown]
# Install the required libraries not available by default on Google Colab.

# %%
# required libraries 
# !pip install transformers
# !pip install sentencepiece
# !pip install tensorboardX
# !pip install pytorch
# !pip install torch
# !pip install GPUtil
# !pip install contractions
# !git clone https://github.com/huggingface/neuralcoref.git
# !pip install -U spacy==2.3.5
# !python -m spacy download en
# !python -m spacy download en_core_web_sm

# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install psutil
# !pip install humanize

# install neuralcoref locally
# %cd neuralcoref
# !pip install -r requirements.txt
# !pip install -e .
# %cd ..

# %% [markdown]
# ##Run code

# %% [markdown]
# Run code and pass additional parameters with following line.

# %%
# !python main.py --model-type bert --filename test --output-dir drive/MyDrive/abcde/outputs/ --epochs 5 --expand --coref --sentiment --lemmatize
# --model-type bert|roberta|albert
# --expand 
# --coref 
# --sentiment 
# --lemmatize
